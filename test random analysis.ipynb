# %%
#derivative function
# %matplotlib inline


import matplotlib.pyplot as plt
import numpy

dx = 0.1
#y = [97, 47, 17, 67,  3,  1, 32, 82, 59, 19, 54, 61, 60, 84, 77, 15, 21,55, 46, 64, 62, 45, 41, 94, 22, 49,  0, 74, 52, 50, 79, 70, 93,  7,63, 95, 66, 83, 56, 34, 78, 36,  8, 27, 35, 75, 85, 14,  5,  2,  6,18, 44, 40, 43, 10, 86, 80, 96, 16, 38, 65, 53,  4, 51, 73, 72, 89,12, 76, 24, 39,  9, 29, 13, 87, 88, 20, 26, 92, 11, 42, 98, 33, 58,68, 99, 30, 31, 25, 91, 23, 90, 48, 69, 37, 71, 57, 81, 28]
#y=frame1['b'].values
y=[5,4,3,8,9,7,6,8,7,6,7,8,6,7,7,7,7,8,8,7,7,6,6,3,3,4,5,6,7,5,4,3,3,3,4,5,4,4,4,4]
z=[2,3,2,3,2,3,7,8,9,7,8,7,8,7,8,7,5,6,7,8,7,6,5,4,6,7,8,4,3,3,4,3,3,1,2,2,2,2,2,2]
dy = diff(y)/dx
ddy = diff(dy)/dx
print dy
plt.figure(1)
plt.subplot(211)
plt.plot(y)
plt.plot(dy)

plt.subplot(212)

#plt.plot(ddy)
plt.plot(numpy.convolve(dy,y))
print numpy.convolve(dy,y)
plt.figure(2)
plt.plot(numpy.r_[True, dy[1:] < dy[:-1]] & numpy.r_[dy[:-1] < dy[1:], True])
plt.plot(y)
plt.plot(z)
# Out:
# [-10. -10.  50.  10. -20. -10.  20. -10. -10.  10.  10. -20.  10.   0.   0.
#    0.  10.   0. -10.   0. -10.   0. -30.   0.  10.  10.  10.  10. -20. -10.
#  -10.   0.   0.  10.  10. -10.   0.   0.   0.]
# [ -50.  -90.  180.  140.  -80.  140.  400.  140.  -70.  240.  270.  -60.
#    90.  330.   70.   40.  230.  240.   30.  220.  250.   80. -110.  -10.
#    40. -240. -230.    0.    0.  -50.  100.  -40. -220. -300.  -70. -260.
#  -160.   10. -110. -290. -130.   20. -220. -200.  -60.  -50. -230. -190.
#  -230. -260. -300.  -30.  -10.   20.  -20. -110. -270. -330. -190. -100.
#   -20.   10.   90.   10.  -30.  -70.  -90. -120.  -20.   10.   30.   40.
#    40.    0.  -40.    0.    0.    0.]
